# %%
import numpy as np
rand = np.random.RandomState(42)
mean = [0, 0]
cov = [[1,2], [2,5]]

X = rand.multivariate_normal(mean, cov, 100)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

plt.scatter(X[:,0], X[:, 1]);

# %%
indices = np.random.choice(X.shape[0], 20, replace=False)
indices
# Out:
# array([91, 47, 97, 51, 92, 28, 94, 68, 44, 40,  7, 52, 79, 80, 61, 41, 33,
#        24,  9, 64])

# %%
selection = X[indices]

# %%
plt.scatter(X[:,0], X[:, 1])
plt.scatter(selection[:, 0], selection[:, 1],
           facecolor='none', s = 200)

# %%
np.random.randn(10)
# Out:
# array([-0.47610316, -2.65822856,  2.43612555,  0.14269348,  0.53866901,
#         0.92610888, -0.46159839, -0.07461689,  0.98826612, -0.1181218 ])
